# %%
from scripts import download
# download()

# %%
import xarray as xr

ds = xr.open_mfdataset("../data/raw/2020_1-4/data_stream-oper_stepType-instant.nc", engine="netcdf4")

# %%
ds
# Out:
# <xarray.Dataset> Size: 369MB
# Dimensions:     (valid_time: 1573, latitude: 121, longitude: 121)
# Coordinates:
#   * valid_time  (valid_time) datetime64[ns] 13kB 2020-01-01 ... 2020-04-30T12...
#     expver      (valid_time) <U4 25kB dask.array<chunksize=(1573,), meta=np.ndarray>
#   * latitude    (latitude) float64 968B 35.0 34.75 34.5 34.25 ... 5.5 5.25 5.0
#   * longitude   (longitude) float64 968B 65.0 65.25 65.5 ... 94.5 94.75 95.0
#     number      int64 8B ...
# Data variables:
#     u10         (valid_time, latitude, longitude) float32 92MB dask.array<chunksize=(787, 61, 61), meta=np.ndarray>
#     v10         (valid_time, latitude, longitude) float32 92MB dask.array<chunksize=(787, 61, 61), meta=np.ndarray>
#     d2m         (valid_time, latitude, longitude) float32 92MB dask.array<chunksize=(787, 61, 61), meta=np.ndarray>
#     t2m         (valid_time, latitude, longitude) float32 92MB dask.array<chunksize=(787, 61, 61), meta=np.ndarray>
# Attributes:
# ...

# %%
from pprint import pprint

pprint(ds.attrs)
# Out:
# {'Conventions': 'CF-1.7',
#  'GRIB_centre': 'ecmf',
#  'GRIB_centreDescription': 'European Centre for Medium-Range Weather Forecasts',
#  'GRIB_subCentre': np.int64(0),
#  'history': '2026-03-18T20:14 GRIB to CDM+CF via '
#             'cfgrib-0.9.15.1/ecCodes-2.42.0 with {"source": '
#             '"tmp8e_wacf0/data.grib", "filter_by_keys": {"stream": ["oper"], '
#             '"stepType": ["instant"]}, "encode_cf": ["parameter", "time", '
#             '"geography", "vertical"]}',
#  'institution': 'European Centre for Medium-Range Weather Forecasts'}
