# %%
from constants import DATA_CONFIG
years: dict[str: int] = DATA_CONFIG["span"]

# %%
from scripts import download
download(2007, 2019, output_dir="../data/compressed")
# Out:
# >> Started download: ../data/compressed/2007_1-5.zip
# 2026-03-23 18:12:46,504 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-single-levels-timeseries?tab=overview)
# 2026-03-23 18:12:46,506 INFO Request ID is 1f5dd1ec-46d2-4b51-93e8-7d4838835f80
# 2026-03-23 18:12:46,723 INFO status has been updated to accepted
# 2026-03-23 18:13:01,043 INFO status has been updated to successful
# a4b5900248fc996fbf8d534eaa889a1a.zip:  61%|██████    | 263M/431M [26:59<15:12, 194kB/s]
